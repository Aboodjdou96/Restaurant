# %%
from tkinter import *
from PIL import ImageTk, Image

top = Tk ()
top.minsize (400, 300)
top.config(bg="#35b7d4")
frame = Frame (top, width=30, height=3)
frame.pack ()
img = ImageTk.PhotoImage (Image.open ("R2.png"))

label = Label (frame, image=img, width=500, height=300, bg="#35b7d4")
label.pack ()

label1 = Label (text="Welcome Fast Food", bg="#35b7d4", font=("Times New Roman", 20, "italic"), fg="black")
label1.pack ()


def Top1screen():
    top.destroy ()
    top1 = Tk ()
    top1.minsize(600, 400)
    top1.config(bg="#35b7d4")

    top1.minsize (250, 170)
    label4 = Label (top1, text="PLEASE CHOOSE TYPE OF YOUR FAVORITE FOOD :", bg="#35b7d4", font=("Times New Roman", 20, "italic")).grid (row=0, column=0)
    label2 = Label (top1, text="[1] Oriental Food",bg="#35b7d4" , font=("Times New Roman", 20, "italic"), fg="black").grid (row=1, column=0)
    label3 = Label (top1, text="[2] Western Food",bg="#35b7d4" , font=("Times New Roman", 20, "italic"), fg="black").grid (row=2, column=0)

    x = Entry (top1)
    x.grid (padx=0, pady=9)

    def choise():
        y = float (x.get ())
        sum1 = 0
        if y == 1:
            top1.destroy ()
            top2 = Tk ()
            top2.minsize (600, 400)
            top2.title("Menu Oriental")
            top2.config(bg="#35b7d4")
            label5 = Label (top2, text="Menu Oriental Food :", bg="#35b7d4",font=("Times New Roman", 20, "italic"), fg="black").grid (row=0, column=0)

            label6 = Label (top2, text="[1] Mansf       20Jod", bg="#35b7d4" ,font=("Times New Roman", 20, "italic"), fg="black").grid (row=1, column=0)
            label7 = Label (top2, text="[2] M8loba      15Jod",bg="#35b7d4" , font=("Times New Roman", 20, "italic"), fg="black").grid (row=2, column=0)
            label8 = Label (top2, text="[3] Kbseh      17Jod",bg="#35b7d4" , font=("Times New Roman", 20, "italic"), fg="black").grid (row=3, column=0)
            label9 = Label (top2, text="[4] Oozi      15Jod",bg="#35b7d4" , font=("Times New Roman", 20, "italic"), fg="black").grid (row=4, column=0)
            label10 = Label (top2, text="[5] Mjdra     20Jod",bg="#35b7d4" , font=("Times New Roman", 20, "italic"), fg="black").grid (row=5, column=0)

            ma=[]
            mf=[]
            def s1():
                b9 = Button (top2, text="Remove", font=("Times New Roman", 13, "italic"), bg="#35d4a1",command=a1)
                b9.grid (row=1, column=2)
                s1=20
                ma1=ma.append(s1)
                mf.append("Mansf\n")
                return s1

            def s2():

                b10 = Button (top2, text="Remove",font=("Times New Roman", 13, "italic"), bg="#35d4a1",
                              command=a2)
                b10.grid (row=2, column=2)
                s2=15
                ma2=ma.append(s2)
                mf.append ("M8loba\n")

                return s2

            def s3():
                b11 = Button (top2, text="Remove", font=("Times New Roman", 13, "italic"), bg="#35d4a1",
                              command=a3)
                b11.grid (row=3, column=2)
                s3=17
                ma3=ma.append(s3)
                mf.append ("Kbseh\n")
                return s3

            def s4():

                b12 = Button (top2, text="Remove", font=("Times New Roman", 13, "italic"), bg="#35d4a1", command=a4)
                b12.grid (row=4, column=2)
                s4=15
                ma4 = ma.append(s4)
                mf.append ("Oozi\n")
                return s4

            def s5():

                b13 = Button (top2, text="Remove", font=("Times New Roman", 13, "italic"), bg="#35d4a1", command=a5)
                b13.grid (row=5, column=2)
                s5=20
                ma5=ma.append(s5)
                mf.append ("Mjdra\n")
                return s5


            def total():
                ra = Button (top2, text="Clear", font=("Times New Roman", 20, "italic"), bg="#35d4a1", command=clearlist1)
                ra.grid (row=10, column=0)
                t1.delete("1.0", "end")
                ff=sum(ma)
                t1.insert (END, str (ff) + ' Jod')
                return ff





            b3 = Button (top2, text="Add", font=("Times New Roman", 13, "italic"), bg="#35d4a1", command=s1)
            b3.grid (row=1, column=1)
            b4 = Button (top2, text="Add", font=("Times New Roman", 13, "italic"), bg="#35d4a1", command=s2)
            b4.grid (row=2, column=1)
            b5 = Button (top2, text="Add", font=("Times New Roman", 13, "italic"), bg="#35d4a1", command=s3)
            b5.grid (row=3, column=1)
            b6 = Button (top2, text="Add", font=("Times New Roman", 13, "italic"), bg="#35d4a1", command=s4)
            b6.grid (row=4, column=1)
            b7 = Button (top2, text="Add", font=("Times New Roman", 13, "italic"), bg="#35d4a1", command=s5)
            b7.grid (row=5, column=1)

            t1=Text(top2, width=20,height=1.5)
            t1.grid(row=8, column=1)

            def a1():
                ma6=ma.remove(20)
                mf.remove("Mansf\n")

            def a2():
                ma7=ma.remove(15)
                print ("M8loba")
                mf.remove("M8loba\n")


            def a3():
                ma8=ma.remove(17)
                mf.remove ("Kbseh\n")


            def a4():
                ma9=ma.remove(15)
                mf.remove ("Oozi\n")

            def a5():
                ma10=ma.remove(20)
                mf.remove ("Mjdra\n")


            def clearlist1():
                 mx12=ma.clear()
                 mf.clear()
                 ms=0
                 t1.delete ("1.0", "end")
                 t1.insert (END, str (ms) + ' Jod')

            def list():
                top5 = Tk ()
                top5.minsize (600, 400)
                top5.config (bg="#35b7d4")

                labellis = Label (top5, text="".join (mf), bg="#35b7d4", font=("Times New Roman", 20, "italic"),fg="black").grid (row=5, column=0)


            b8 = Button (top2, text="Total", font=("Times New Roman", 20, "italic"), bg="#35d4a1", command=total)
            b8.grid (row=8, column=0)


            b9 = Button (top2, text="Remove",state=DISABLED ,font=("Times New Roman", 13, "italic"), bg="#35d4a1", command=a1)
            b9.grid (row=1, column=2)
            b10 = Button (top2, text="Remove",state=DISABLED, font=("Times New Roman", 13, "italic"), bg="#35d4a1", command=a2)
            b10.grid (row=2, column=2)
            b11 = Button (top2, text="Remove", state=DISABLED ,font=("Times New Roman", 13, "italic"), bg="#35d4a1", command=a3)
            b11.grid (row=3, column=2)
            b12 = Button (top2, text="Remove",state=DISABLED ,font=("Times New Roman", 13, "italic"), bg="#35d4a1", command=a4)
            b12.grid (row=4, column=2)
            b13 = Button (top2, text="Remove",state=DISABLED ,font=("Times New Roman", 13, "italic"), bg="#35d4a1", command=a5)
            b13.grid (row=5, column=2)

            ra = Button (top2, text="Clear",state=DISABLED,font=("Times New Roman", 20, "italic"), bg="#35d4a1", command=clearlist1)
            ra.grid (row=10, column=0)
            b8 = Button (top2, text="List", font=("Times New Roman", 20, "italic"), bg="#35d4a1", command=list)
            b8.grid (row=9, column=0)








        elif y == 2:
            top3=Tk()
            top3.minsize(600, 400)
            top3.config(bg="#35b7d4")
            top3.title("Menu Western")
            top1.destroy()


            label5 = Label (top3, text="Menu Western Food : ", bg="#35b7d4" ,font=("Times New Roman", 20, "italic"), fg="black").grid (row=0, column=0)

            label6 = Label (top3, text="[1] Hamburger       7 Jod", bg="#35b7d4" ,font=("Times New Roman", 20, "italic"), fg="black").grid (row=1, column=0)

            label7 = Label (top3, text="[2] Hot dog      5 Jod", bg="#35b7d4" ,font=("Times New Roman", 20, "italic"), fg="black").grid (row=2, column=0)

            label8 = Label (top3, text="[3] Sausage      8 Jod", bg="#35b7d4" ,font=("Times New Roman", 20, "italic"), fg="black").grid (row=3, column=0)

            label9 = Label (top3, text="[4] zengar      6 Jod",bg="#35b7d4" , font=("Times New Roman", 20, "italic"), fg="black").grid (row=4, column=0)

            label10 = Label (top3, text="[5] Taco     7 Jod",bg="#35b7d4" , font=("Times New Roman", 20, "italic"), fg="black").grid (row=5, column=0)


            mx=[]
            mz=[]
            def s1():
                b9 = Button (top3, text="Remove", font=("Times New Roman", 13, "italic"), bg="#35d4a1",command=r1)
                b9.grid (row=1, column=2)
                s1=7
                mx1=mx.append(s1)
                z=mz.append("Hamburger\n")
                return s1

            def s2():

                b10 = Button (top3, text="Remove",font=("Times New Roman", 13, "italic"), bg="#35d4a1",command=r2)
                b10.grid (row=2, column=2)
                s2=5
                mx2=mx.append(s2)
                e = mz.append("Hot dog\n")
                return s2

            def s3():
                b11 = Button (top3, text="Remove", font=("Times New Roman", 13, "italic"), bg="#35d4a1",command=r3)
                b11.grid (row=3, column=2)
                s3=8
                mx3=mx.append(s3)
                u = mz.append ("Sausage\n")
                return s3

            def s4():

                b12 = Button (top3, text="Remove", font=("Times New Roman", 13, "italic"), bg="#35d4a1", command=r4)
                b12.grid (row=4, column=2)
                s4=6
                mx4 = mx.append(s4)
                i = mz.append("zengar\n")
                return s4

            def s5():

                b13 = Button (top3, text="Remove", font=("Times New Roman", 13, "italic"), bg="#35d4a1", command=r5)
                b13.grid (row=5, column=2)
                s5=7
                mx5=mx.append(s5)
                p = mz.append("Taco\n")
                return s5

            def total():
                rc = Button (top3, text="Clear", font=("Times New Roman", 20, "italic"), bg="#35d4a1", command=clearlist)
                rc.grid (row=11, column=0)
                t1.delete("1.0", "end")
                ff=sum(mx)
                t1.insert (END, str (ff) + ' Jod')
                return ff







            b3 = Button (top3, text="Add", font=("Times New Roman", 13, "italic"), bg="#35d4a1", command=s1)
            b3.grid (row=1, column=1)
            b4 = Button (top3, text="Add", font=("Times New Roman", 13, "italic"), bg="#35d4a1", command=s2)
            b4.grid (row=2, column=1)
            b5 = Button (top3, text="Add", font=("Times New Roman", 13, "italic"), bg="#35d4a1", command=s3)
            b5.grid (row=3, column=1)
            b6 = Button (top3, text="Add", font=("Times New Roman", 13, "italic"), bg="#35d4a1", command=s4)
            b6.grid (row=4, column=1)
            b7 = Button (top3, text="Add", font=("Times New Roman", 13, "italic"), bg="#35d4a1", command=s5)
            b7.grid (row=5, column=1)

            t1=Text(top3, width=20,height=1.5)
            t1.grid(row=10, column=1)

            def r1():
                mx6=mx.remove(7)
                mh=mz.remove("Hamburger\n")

            def r2():
                mx7=mx.remove(5)
                mh = mz.remove ("Hot dog\n")


            def r3():
                mx8=mx.remove(8)
                mh = mz.remove ("Sausage\n")


            def r4():
                mx9=mx.remove(6)
                mh = mz.remove ("zengar\n")

            def r5():
                mx10=mx.remove(7)
                mh = mz.remove ("Taco\n")


            def clearlist():
                 mx11=mx.clear()
                 mz.clear()
                 mx44=0
                 t1.delete ("1.0", "end")
                 t1.insert (END, str (mx44) + ' Jod')












            b9 = Button (top3, text="Remove",state=DISABLED ,font=("Times New Roman", 13, "italic"), bg="#35d4a1", command=r1)
            b9.grid (row=1, column=2)
            b10 = Button (top3, text="Remove",state=DISABLED, font=("Times New Roman", 13, "italic"), bg="#35d4a1", command=r2)
            b10.grid (row=2, column=2)
            b11 = Button (top3, text="Remove", state=DISABLED ,font=("Times New Roman", 13, "italic"), bg="#35d4a1", command=r3)
            b11.grid (row=3, column=2)
            b12 = Button (top3, text="Remove",state=DISABLED ,font=("Times New Roman", 13, "italic"), bg="#35d4a1", command=r4)
            b12.grid (row=4, column=2)
            b13 = Button (top3, text="Remove",state=DISABLED ,font=("Times New Roman", 13, "italic"), bg="#35d4a1", command=r5)
            b13.grid (row=5, column=2)



            b8 = Button (top3, text="Total", font=("Times New Roman", 20, "italic"), bg="#35d4a1", command=total)
            b8.grid (row=9, column=0)





            def list1():
                top4=Tk()
                top4.minsize(600,400)
                top4.config(bg="#35b7d4")



                labellist = Label(top4, text="".join(mz),bg="#35b7d4" , font=("Times New Roman", 20, "italic"), fg="black").grid (row=5, column=0)










            b8 = Button (top3, text="List", font=("Times New Roman", 20, "italic"), bg="#35d4a1", command=list1)
            b8.grid (row=10, column=0)

            rc = Button (top3, text="Clear",state=DISABLED ,font=("Times New Roman", 20, "italic"), bg="#35d4a1", command=clearlist)
            rc.grid (row=11, column=0)







        else:
            labelerorr=Label (top1, bg="red",text="Please select one of two options", font=("Times New Roman", 20, "italic"), fg="black").grid (row=7, column=0)

    b2 = Button (top1, text="Select", font=("Times New Roman", 20, "italic"), bg="#35d4a1", command=choise)
    b2.grid (row=9, column=0)


b1 = Button (text="Order", bg="#35d4a1", font=("Times New Roman", 20, "italic"), command=Top1screen)
b1.pack ()

top.mainloop ()
